# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8s-pose.pt")
model.train(data="Dataset/data.yaml", epochs=128, imgsz=640, batch=16, device=0)
# Out:
# ...
# Ultralytics 8.4.102  Python-3.14.5 torch-2.12.0+cu132 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
# ...

# %%
model = YOLO("runs/pose/train/weights/best.pt")

results = model.predict(source="Dataset/test/images", imgsz=640, device=0, save=True, save_txt=True, conf=0.25)
print("Testing completed")

# %%
model = YOLO("../runs/pose/train/weights/best.pt")
model.export(format="onnx", imgsz=640, opset=17, simplify=True)
# Out:
# Ultralytics 8.4.102  Python-3.14.5 torch-2.12.0+cu132 CPU (11th Gen Intel Core(TM) i7-11800H 2.30GHz)
# YOLOv8s-pose summary (fused): 82 layers, 11,412,840 parameters, 0 gradients, 29.4 GFLOPs
#
# PyTorch: starting from '..\runs\pose\train\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 12, 8400) (22.1 MB)
#
# ONNX: starting export with onnx 1.22.0 opset 17...
# ONNX: slimming with onnxslim 0.1.95...
# ONNX: export success  1.3s, saved as '..\runs\pose\train\weights\best.onnx' (43.9 MB)
#
# Export complete (1.6s)
# Results saved to D:\Computer Vision\Projects\industrial-pose-estimation\runs\pose\train\weights\best.onnx
# Predict:         yolo predict task=pose model=..\runs\pose\train\weights\best.onnx imgsz=640
# Validate:        yolo val task=pose model=..\runs\pose\train\weights\best.onnx imgsz=640 data=Dataset\data.yaml
# Visualize:       https://netron.app
# '..\\runs\\pose\\train\\weights\\best.onnx'
